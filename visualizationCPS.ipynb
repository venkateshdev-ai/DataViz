# %%
#combining plot style

# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
# now combining the plot

ds = randn(100)

# %%
sns.distplot(ds, bins=25)

# %%
sns.distplot(ds, rug=True, hist=False)

# %%
sns.distplot(ds, rug=False, hist=True)

# %%
#to control specific plots in displot, use[plot]_kws argument with dictionaries

sns.distplot(ds, bins=25, 
            kde_kws={'color':'indianred', 'label':'KDE PLOT'},
            hist_kws={'color':'blue','label':'HISTOGRAM'})

# %%
from pandas import Series

ser1 = Series(ds, name ='My_Data')

# %%
sns.distplot(ds, bins=25)
